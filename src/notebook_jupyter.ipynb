# %% [markdown]
# # Classificação de Textos por Estilo Literário
#
# Este projeto utiliza algoritmos de aprendizado supervisionado para classificar textos
# de acordo com seus estilos literários: Poesia, Prosa e Jornalismo.
#
# ## Etapas:
# 1. Carregar os dados.
# 2. Pré-processar os textos.
# 3. Vetorizar os textos (Bag of Words).
# 4. Treinar e avaliar os seguintes modelos:
#    - Decision Tree
#    - K-Nearest Neighbors
#    - Naive Bayes
#    - Logistic Regression
#    - Multi-layer Perceptron
# 5. Comparar os resultados.

# %% [markdown]
# # Parte 1

# %%
# %pip install PyPDF2 scikit-learn nltk pandas matplotlib seaborn
# Out:
# Requirement already satisfied: PyPDF2 in c:\users\gustavo\appdata\local\programs\python\python311\lib\site-packages (3.0.1)
# Requirement already satisfied: scikit-learn in c:\users\gustavo\appdata\local\programs\python\python311\lib\site-packages (1.4.2)
# Requirement already satisfied: nltk in c:\users\gustavo\appdata\local\programs\python\python311\lib\site-packages (3.9.1)
# Requirement already satisfied: pandas in c:\users\gustavo\appdata\local\programs\python\python311\lib\site-packages (2.2.2)
# Requirement already satisfied: matplotlib in c:\users\gustavo\appdata\local\programs\python\python311\lib\site-packages (3.8.4)
# Requirement already satisfied: seaborn in c:\users\gustavo\appdata\local\programs\python\python311\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\gustavo\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\gustavo\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.13.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\gustavo\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\gustavo\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: click in c:\users\gustavo\appdata\local\programs\python\python311\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\gustavo\appdata\local\programs\python\python311\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\gustavo\appdata\local\programs\python\python311\lib\site-packages (from nltk) (4.66.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gustavo\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gustavo\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gustavo\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gustavo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\gustavo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gustavo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gustavo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\gustavo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\gustavo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gustavo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\gustavo\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: colorama in c:\users\gustavo\appdata\local\programs\python\python311\lib\site-packages (from click->nltk) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Importação das Bibliotecas

# %%
# ===============================
# Célula 1: Importação das Bibliotecas
# ===============================
import os
import PyPDF2
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import accuracy_score, f1_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Baixar pacotes necessários do NLTK
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Gustavo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Gustavo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# Função para Extração de Texto de PDFs

# %%
def pdf_para_txt(caminho_pdf):
    """
    Lê um arquivo PDF e retorna o texto extraído.
    """
    with open(caminho_pdf, 'rb') as f:
        leitor = PyPDF2.PdfReader(f)
        texto = ""
        for pagina in range(len(leitor.pages)):
            texto += leitor.pages[pagina].extract_text()
    return texto

# %% [markdown]
# Função para Limpeza e Remoção de Stopwords

# %%
def limpar_texto(texto):
    """
    Limpa o texto, remove stopwords e caracteres especiais.
    """
    stop_words = set(stopwords.words('portuguese'))
    palavras = word_tokenize(texto.lower())
    palavras_limpa = [palavra for palavra in palavras if palavra.isalnum() and palavra not in stop_words]
    return " ".join(palavras_limpa)

# %% [markdown]
# Configuração dos Diretórios

# %%
# ===============================
# Célula 4: Configuração dos Diretórios
# ===============================
# Diretórios com os PDFs (ajuste os caminhos conforme necessário)
diretorios = {
    'poesia': 'pdfs/poesia/',
    'prosa': 'pdfs/prosa/',
    'jornalismo': 'pdfs/jornalismo/'
}

# Pasta base para salvar os textos extraídos
output_dir = 'textos_extraidos'

# Criar diretório principal e subpastas
os.makedirs(output_dir, exist_ok=True)
for classe in diretorios.keys():
    os.makedirs(os.path.join(output_dir, classe), exist_ok=True)

# %% [markdown]
# Extração de Texto e Salvamento em Arquivos TXT

# %%
# ===============================
# Célula 5: Extração de Texto e Salvamento em Arquivos TXT
# ===============================
textos = []
classes = []

for classe, caminho in diretorios.items():
    for arquivo in os.listdir(caminho):
        if arquivo.endswith('.pdf'):
            # Extrair e limpar texto do PDF
            texto = pdf_para_txt(os.path.join(caminho, arquivo))
            texto_limpo = limpar_texto(texto)
            
            # Caminho para salvar o arquivo de texto na subpasta correspondente
            subpasta = os.path.join(output_dir, classe)
            output_path = os.path.join(subpasta, arquivo.replace('.pdf', '.txt'))
            
            # Salvar texto limpo no arquivo .txt
            with open(output_path, 'w', encoding='utf-8') as f:
                f.write(texto_limpo)
            
            # Armazenar texto e classe para uso posterior
            textos.append(texto_limpo)
            classes.append(classe)

print(f"Textos extraídos e organizados em subpastas de '{output_dir}'.")
# Out:
# Textos extraídos e organizados em subpastas de 'textos_extraidos'.

# %% [markdown]
# Criação da Matriz Bag of Words (BoW)

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(textos)

print("Matriz BoW criada com sucesso!")
print("Dimensões da matriz:", X.shape)
# Out:
# Matriz BoW criada com sucesso!
# Dimensões da matriz: (291, 214536)

# %% [markdown]
# Divisão dos Dados em Treino e Teste

# %%
X_train, X_test, y_train, y_test = train_test_split(X, classes, test_size=0.3, random_state=42)
print("Dados divididos em treino e teste.")
# Out:
# Dados divididos em treino e teste.

# %% [markdown]
# # Parte 2

# %% [markdown]
# #### Coleta de Medidas de Desempenho com validação cruzada

# %%
from sklearn.model_selection import cross_val_score

def treinar_modelo_com_crossval(modelo, nome_modelo):
    """
    Treina e avalia o modelo usando cross-validation com 10 folds.
    Retorna as médias das métricas de avaliação.
    """
    # Calculando acurácia
    accuracies = cross_val_score(modelo, X_train, y_train, cv=10, scoring='accuracy')
    # Calculando F1-Score
    f1_scores = cross_val_score(modelo, X_train, y_train, cv=10, scoring='f1_weighted')

    resultado = {
        'nome_modelo': nome_modelo,
        'acuracia_media': np.mean(accuracies),
        'acuracia_std': np.std(accuracies),
        'f1_media': np.mean(f1_scores),
        'f1_std': np.std(f1_scores)
    }

    print(f"\n{nome_modelo}:")
    print(f"Acurácia média: {resultado['acuracia_media']:.4f} (+/- {resultado['acuracia_std']:.4f})")
    print(f"F1-Score médio: {resultado['f1_media']:.4f} (+/- {resultado['f1_std']:.4f})")
    
    return resultado

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

print("Treinando modelo: KNN")
modelo_knn = KNeighborsClassifier()
treinar_modelo_com_crossval(modelo_knn, "KNN")
# Out:
# Treinando modelo: KNN
#
# KNN:
# Acurácia média: 0.5652 (+/- 0.0931)
# F1-Score médio: 0.5333 (+/- 0.1269)
# {'nome_modelo': 'KNN',
#  'acuracia_media': 0.5652380952380952,
#  'acuracia_std': 0.09311441770521092,
#  'f1_media': 0.5332767695267695,
#  'f1_std': 0.12694557197197834}

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

print("Treinando modelo: Decision Tree")
modelo_dt = DecisionTreeClassifier()
treinar_modelo_com_crossval(modelo_dt, "Decision Tree")
# Out:
# Treinando modelo: Decision Tree
#
# Decision Tree:
# Acurácia média: 0.8029 (+/- 0.0630)
# F1-Score médio: 0.7832 (+/- 0.1058)
# {'nome_modelo': 'Decision Tree',
#  'acuracia_media': 0.8028571428571427,
#  'acuracia_std': 0.06302826634357513,
#  'f1_media': 0.7832106550856551,
#  'f1_std': 0.10582272137149301}

# %% [markdown]
# Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

print("Treinando modelo: Naive Bayes")
modelo_nb = MultinomialNB()
treinar_modelo_com_crossval(modelo_nb, "Naive Bayes")
# Out:
# Treinando modelo: Naive Bayes
#
# Naive Bayes:
# Acurácia média: 0.7031 (+/- 0.0976)
# F1-Score médio: 0.6990 (+/- 0.1049)
# {'nome_modelo': 'Naive Bayes',
#  'acuracia_media': 0.7030952380952381,
#  'acuracia_std': 0.09758448865626061,
#  'f1_media': 0.6990087302331884,
#  'f1_std': 0.10489116240046446}

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

print("Treinando modelo: Logistic Regression")
modelo_lr = LogisticRegression(max_iter=1000)
treinar_modelo_com_crossval(modelo_lr, "Logistic Regression")
# Out:
# Treinando modelo: Logistic Regression
#
# Logistic Regression:
# Acurácia média: 0.8669 (+/- 0.0550)
# F1-Score médio: 0.8638 (+/- 0.0574)
# {'nome_modelo': 'Logistic Regression',
#  'acuracia_media': 0.866904761904762,
#  'acuracia_std': 0.05499381536037624,
#  'f1_media': 0.863755689571866,
#  'f1_std': 0.057359480635165785}

# %% [markdown]
# MLP Classifier

# %%
from sklearn.neural_network import MLPClassifier

print("Treinando modelo: MLP Classifier")
modelo_mlp = MLPClassifier(max_iter=500, early_stopping=True, n_iter_no_change=10, verbose=True)
treinar_modelo_com_crossval(modelo_mlp, "MLP Classifier")
# Out:
# Treinando modelo: MLP Classifier
# Iteration 1, loss = 1.10145265
# Validation score: 0.210526
# Iteration 2, loss = 1.07186477
# Validation score: 0.210526
# Iteration 3, loss = 1.03629069
# Validation score: 0.210526
# Iteration 4, loss = 0.99727448
# Validation score: 0.263158
# Iteration 5, loss = 0.95692242
# Validation score: 0.368421
# Iteration 6, loss = 0.91575201
# Validation score: 0.473684
# Iteration 7, loss = 0.87467147
# Validation score: 0.578947
# Iteration 8, loss = 0.83431863
# Validation score: 0.631579
# Iteration 9, loss = 0.79452887
# Validation score: 0.631579
# Iteration 10, loss = 0.75527934
# Validation score: 0.684211
# Iteration 11, loss = 0.71675095
# Validation score: 0.736842
# Iteration 12, loss = 0.67904247
# Validation score: 0.789474
# Iteration 13, loss = 0.64248276
# Validation score: 0.789474
# Iteration 14, loss = 0.60723361
# Validation score: 0.789474
# Iteration 15, loss = 0.57335242
# Validation score: 0.736842
# Iteration 16, loss = 0.54090724
# Validation score: 0.736842
# Iteration 17, loss = 0.50996255
# Validation score: 0.736842
# Iteration 18, loss = 0.48065073
# Validation score: 0.736842
# Iteration 19, loss = 0.45294567
# Validation score: 0.736842
# Iteration 20, loss = 0.42673013
# Validation score: 0.736842
# Iteration 21, loss = 0.40196939
# Validation score: 0.736842
# Iteration 22, loss = 0.37864396
# Validation score: 0.736842
# Iteration 23, loss = 0.35673142
# Validation score: 0.736842
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.10089372
# Validation score: 0.263158
# Iteration 2, loss = 1.07677024
# Validation score: 0.263158
# Iteration 3, loss = 1.04833282
# Validation score: 0.526316
# Iteration 4, loss = 1.01723564
# Validation score: 0.578947
# Iteration 5, loss = 0.98403016
# Validation score: 0.578947
# Iteration 6, loss = 0.94966556
# Validation score: 0.684211
# Iteration 7, loss = 0.91485745
# Validation score: 0.736842
# Iteration 8, loss = 0.87997367
# Validation score: 0.736842
# Iteration 9, loss = 0.84552424
# Validation score: 0.736842
# Iteration 10, loss = 0.81123591
# Validation score: 0.736842
# Iteration 11, loss = 0.77685819
# Validation score: 0.789474
# Iteration 12, loss = 0.74277766
# Validation score: 0.789474
# Iteration 13, loss = 0.70931516
# Validation score: 0.789474
# Iteration 14, loss = 0.67654497
# Validation score: 0.789474
# Iteration 15, loss = 0.64452195
# Validation score: 0.789474
# Iteration 16, loss = 0.61323147
# Validation score: 0.789474
# Iteration 17, loss = 0.58271894
# Validation score: 0.789474
# Iteration 18, loss = 0.55311024
# Validation score: 0.789474
# Iteration 19, loss = 0.52449310
# Validation score: 0.789474
# Iteration 20, loss = 0.49696112
# Validation score: 0.789474
# Iteration 21, loss = 0.47051904
# Validation score: 0.789474
# Iteration 22, loss = 0.44513015
# Validation score: 0.789474
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.12170875
# Validation score: 0.421053
# Iteration 2, loss = 1.09820196
# Validation score: 0.421053
# Iteration 3, loss = 1.06725747
# Validation score: 0.421053
# Iteration 4, loss = 1.03208046
# Validation score: 0.421053
# Iteration 5, loss = 0.99406337
# Validation score: 0.421053
# Iteration 6, loss = 0.95421460
# Validation score: 0.526316
# Iteration 7, loss = 0.91356019
# Validation score: 0.736842
# Iteration 8, loss = 0.87287202
# Validation score: 0.842105
# Iteration 9, loss = 0.83240330
# Validation score: 0.894737
# Iteration 10, loss = 0.79181555
# Validation score: 0.947368
# Iteration 11, loss = 0.75176835
# Validation score: 1.000000
# Iteration 12, loss = 0.71305817
# Validation score: 1.000000
# Iteration 13, loss = 0.67531092
# Validation score: 1.000000
# Iteration 14, loss = 0.63862430
# Validation score: 1.000000
# Iteration 15, loss = 0.60319186
# Validation score: 1.000000
# Iteration 16, loss = 0.56920105
# Validation score: 1.000000
# Iteration 17, loss = 0.53671331
# Validation score: 1.000000
# Iteration 18, loss = 0.50573229
# Validation score: 1.000000
# Iteration 19, loss = 0.47624710
# Validation score: 1.000000
# Iteration 20, loss = 0.44830008
# Validation score: 1.000000
# Iteration 21, loss = 0.42194743
# Validation score: 1.000000
# Iteration 22, loss = 0.39716804
# Validation score: 1.000000
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.09814259
# Validation score: 0.578947
# Iteration 2, loss = 1.07788995
# Validation score: 0.578947
# Iteration 3, loss = 1.05343361
# Validation score: 0.842105
# Iteration 4, loss = 1.02554618
# Validation score: 0.842105
# Iteration 5, loss = 0.99631103
# Validation score: 0.894737
# Iteration 6, loss = 0.96537683
# Validation score: 0.894737
# Iteration 7, loss = 0.93359635
# Validation score: 0.894737
# Iteration 8, loss = 0.90176302
# Validation score: 0.947368
# Iteration 9, loss = 0.86979293
# Validation score: 0.947368
# Iteration 10, loss = 0.83779027
# Validation score: 0.947368
# Iteration 11, loss = 0.80564934
# Validation score: 0.947368
# Iteration 12, loss = 0.77389311
# Validation score: 0.947368
# Iteration 13, loss = 0.74248212
# Validation score: 0.947368
# Iteration 14, loss = 0.71164005
# Validation score: 0.947368
# Iteration 15, loss = 0.68144683
# Validation score: 0.947368
# Iteration 16, loss = 0.65198444
# Validation score: 0.947368
# Iteration 17, loss = 0.62321487
# Validation score: 0.947368
# Iteration 18, loss = 0.59516152
# Validation score: 0.947368
# Iteration 19, loss = 0.56799115
# Validation score: 0.947368
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.10895982
# Validation score: 0.421053
# Iteration 2, loss = 1.08057493
# Validation score: 0.421053
# Iteration 3, loss = 1.04722469
# Validation score: 0.421053
# Iteration 4, loss = 1.01180839
# Validation score: 0.421053
# Iteration 5, loss = 0.97478372
# Validation score: 0.631579
# Iteration 6, loss = 0.93637860
# Validation score: 0.894737
# Iteration 7, loss = 0.89659321
# Validation score: 0.842105
# Iteration 8, loss = 0.85622828
# Validation score: 0.842105
# Iteration 9, loss = 0.81609770
# Validation score: 0.842105
# Iteration 10, loss = 0.77664884
# Validation score: 0.842105
# Iteration 11, loss = 0.73785143
# Validation score: 0.842105
# Iteration 12, loss = 0.69981462
# Validation score: 0.842105
# Iteration 13, loss = 0.66277066
# Validation score: 0.894737
# Iteration 14, loss = 0.62696411
# Validation score: 0.894737
# Iteration 15, loss = 0.59256603
# Validation score: 0.894737
# Iteration 16, loss = 0.55963260
# Validation score: 0.894737
# Iteration 17, loss = 0.52812776
# Validation score: 0.894737
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.11272452
# Validation score: 0.684211
# Iteration 2, loss = 1.08089400
# Validation score: 0.842105
# Iteration 3, loss = 1.04618779
# Validation score: 0.842105
# Iteration 4, loss = 1.01000459
# Validation score: 0.842105
# Iteration 5, loss = 0.97165640
# Validation score: 0.842105
# Iteration 6, loss = 0.93262357
# Validation score: 0.842105
# Iteration 7, loss = 0.89318030
# Validation score: 0.842105
# Iteration 8, loss = 0.85395988
# Validation score: 0.947368
# Iteration 9, loss = 0.81573190
# Validation score: 1.000000
# Iteration 10, loss = 0.77844438
# Validation score: 1.000000
# Iteration 11, loss = 0.74148047
# Validation score: 1.000000
# Iteration 12, loss = 0.70511703
# Validation score: 1.000000
# Iteration 13, loss = 0.66967663
# Validation score: 1.000000
# Iteration 14, loss = 0.63553031
# Validation score: 1.000000
# Iteration 15, loss = 0.60259032
# Validation score: 1.000000
# Iteration 16, loss = 0.57092508
# Validation score: 1.000000
# Iteration 17, loss = 0.54058543
# Validation score: 1.000000
# Iteration 18, loss = 0.51153248
# Validation score: 1.000000
# Iteration 19, loss = 0.48376575
# Validation score: 1.000000
# Iteration 20, loss = 0.45735884
# Validation score: 1.000000
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.10265449
# Validation score: 0.210526
# Iteration 2, loss = 1.07731781
# Validation score: 0.210526
# Iteration 3, loss = 1.04803436
# Validation score: 0.210526
# Iteration 4, loss = 1.01596349
# Validation score: 0.210526
# Iteration 5, loss = 0.98201967
# Validation score: 0.368421
# Iteration 6, loss = 0.94682341
# Validation score: 0.631579
# Iteration 7, loss = 0.91133015
# Validation score: 0.684211
# Iteration 8, loss = 0.87584033
# Validation score: 0.736842
# Iteration 9, loss = 0.84024481
# Validation score: 0.736842
# Iteration 10, loss = 0.80509228
# Validation score: 0.789474
# Iteration 11, loss = 0.77064657
# Validation score: 0.842105
# Iteration 12, loss = 0.73672094
# Validation score: 0.789474
# Iteration 13, loss = 0.70335282
# Validation score: 0.789474
# Iteration 14, loss = 0.67078038
# Validation score: 0.789474
# Iteration 15, loss = 0.63912710
# Validation score: 0.842105
# Iteration 16, loss = 0.60854023
# Validation score: 0.842105
# Iteration 17, loss = 0.57901860
# Validation score: 0.842105
# Iteration 18, loss = 0.55055734
# Validation score: 0.842105
# Iteration 19, loss = 0.52315751
# Validation score: 0.842105
# Iteration 20, loss = 0.49671901
# Validation score: 0.842105
# Iteration 21, loss = 0.47123277
# Validation score: 0.842105
# Iteration 22, loss = 0.44685923
# Validation score: 0.842105
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.10977743
# Validation score: 0.368421
# Iteration 2, loss = 1.08515271
# Validation score: 0.368421
# Iteration 3, loss = 1.05699891
# Validation score: 0.368421
# Iteration 4, loss = 1.02549226
# Validation score: 0.368421
# Iteration 5, loss = 0.99216602
# Validation score: 0.368421
# Iteration 6, loss = 0.95770122
# Validation score: 0.368421
# Iteration 7, loss = 0.92253882
# Validation score: 0.578947
# Iteration 8, loss = 0.88688831
# Validation score: 0.631579
# Iteration 9, loss = 0.85138505
# Validation score: 0.631579
# Iteration 10, loss = 0.81606823
# Validation score: 0.736842
# Iteration 11, loss = 0.78113420
# Validation score: 0.789474
# Iteration 12, loss = 0.74684621
# Validation score: 0.789474
# Iteration 13, loss = 0.71327879
# Validation score: 0.789474
# Iteration 14, loss = 0.68048949
# Validation score: 0.842105
# Iteration 15, loss = 0.64859806
# Validation score: 0.842105
# Iteration 16, loss = 0.61769566
# Validation score: 0.842105
# Iteration 17, loss = 0.58780511
# Validation score: 0.842105
# Iteration 18, loss = 0.55893161
# Validation score: 0.842105
# Iteration 19, loss = 0.53110288
# Validation score: 0.842105
# Iteration 20, loss = 0.50440255
# Validation score: 0.842105
# Iteration 21, loss = 0.47885278
# Validation score: 0.789474
# Iteration 22, loss = 0.45442929
# Validation score: 0.789474
# Iteration 23, loss = 0.43113655
# Validation score: 0.789474
# Iteration 24, loss = 0.40894537
# Validation score: 0.736842
# Iteration 25, loss = 0.38787481
# Validation score: 0.736842
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.11187367
# Validation score: 0.473684
# Iteration 2, loss = 1.08675198
# Validation score: 0.473684
# Iteration 3, loss = 1.05480452
# Validation score: 0.473684
# Iteration 4, loss = 1.01940826
# Validation score: 0.578947
# Iteration 5, loss = 0.98172477
# Validation score: 0.578947
# Iteration 6, loss = 0.94264007
# Validation score: 0.578947
# Iteration 7, loss = 0.90298675
# Validation score: 0.684211
# Iteration 8, loss = 0.86351473
# Validation score: 0.736842
# Iteration 9, loss = 0.82462317
# Validation score: 0.842105
# Iteration 10, loss = 0.78633274
# Validation score: 0.947368
# Iteration 11, loss = 0.74883409
# Validation score: 0.947368
# Iteration 12, loss = 0.71257403
# Validation score: 0.947368
# Iteration 13, loss = 0.67733368
# Validation score: 0.947368
# Iteration 14, loss = 0.64310833
# Validation score: 0.947368
# Iteration 15, loss = 0.61004815
# Validation score: 0.947368
# Iteration 16, loss = 0.57831116
# Validation score: 0.947368
# Iteration 17, loss = 0.54790912
# Validation score: 0.947368
# Iteration 18, loss = 0.51880603
# Validation score: 0.947368
# Iteration 19, loss = 0.49104845
# Validation score: 0.947368
# Iteration 20, loss = 0.46465043
# Validation score: 0.947368
# Iteration 21, loss = 0.43955318
# Validation score: 0.947368
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.11132001
# Validation score: 0.315789
# Iteration 2, loss = 1.08655943
# Validation score: 0.315789
# Iteration 3, loss = 1.05678316
# Validation score: 0.315789
# Iteration 4, loss = 1.02408349
# Validation score: 0.368421
# Iteration 5, loss = 0.98967507
# Validation score: 0.421053
# Iteration 6, loss = 0.95354076
# Validation score: 0.526316
# Iteration 7, loss = 0.91665240
# Validation score: 0.526316
# Iteration 8, loss = 0.87983580
# Validation score: 0.631579
# Iteration 9, loss = 0.84325509
# Validation score: 0.631579
# Iteration 10, loss = 0.80734046
# Validation score: 0.631579
# Iteration 11, loss = 0.77193581
# Validation score: 0.684211
# Iteration 12, loss = 0.73664542
# Validation score: 0.789474
# Iteration 13, loss = 0.70166791
# Validation score: 0.789474
# Iteration 14, loss = 0.66735866
# Validation score: 0.789474
# Iteration 15, loss = 0.63390439
# Validation score: 0.789474
# Iteration 16, loss = 0.60131979
# Validation score: 0.789474
# Iteration 17, loss = 0.56986786
# Validation score: 0.789474
# Iteration 18, loss = 0.53968290
# Validation score: 0.789474
# Iteration 19, loss = 0.51076741
# Validation score: 0.789474
# Iteration 20, loss = 0.48307130
# Validation score: 0.789474
# Iteration 21, loss = 0.45657012
# Validation score: 0.842105
# Iteration 22, loss = 0.43128525
# Validation score: 0.842105
# Iteration 23, loss = 0.40718132
# Validation score: 0.842105
# Iteration 24, loss = 0.38427883
# Validation score: 0.789474
# Iteration 25, loss = 0.36254994
# Validation score: 0.789474
# Iteration 26, loss = 0.34197454
# Validation score: 0.789474
# Iteration 27, loss = 0.32255504
# Validation score: 0.789474
# Iteration 28, loss = 0.30425587
# Validation score: 0.789474
# Iteration 29, loss = 0.28702293
# Validation score: 0.736842
# Iteration 30, loss = 0.27080722
# Validation score: 0.736842
# Iteration 31, loss = 0.25558016
# Validation score: 0.736842
# Iteration 32, loss = 0.24130484
# Validation score: 0.736842
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
#
# MLP Classifier:
# Acurácia média: 0.8417 (+/- 0.0703)
# F1-Score médio: 0.8144 (+/- 0.0738)
# {'nome_modelo': 'MLP Classifier',
#  'acuracia_media': 0.8416666666666666,
#  'acuracia_std': 0.07030263378750697,
#  'f1_media': 0.8144248077630429,
#  'f1_std': 0.07380437077034988}

# %% [markdown]
# # Parte 3

# %% [markdown]
# #### Hiperparâmetros e Otimização

# %% [markdown]
# KNN

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

# Parâmetros para otimizar no KNeighborsClassifier
parametros_knn = {
    'n_neighbors': [3, 5, 7, 9],  
    'weights': ['uniform', 'distance'],  
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],  
}

# GridSearchCV para KNeighborsClassifier
grid_search_knn = GridSearchCV(KNeighborsClassifier(), parametros_knn, 
                               cv=10, n_jobs=-1, verbose=2)
grid_search_knn.fit(X_train, y_train)

# Exibindo os melhores parâmetros encontrados para KNN
print(f"Melhores parâmetros para o KNN: {grid_search_knn.best_params_}")
# Out:
# Fitting 10 folds for each of 32 candidates, totalling 320 fits
# Melhores parâmetros para o KNN: {'algorithm': 'auto', 'n_neighbors': 3, 'weights': 'uniform'}

# %% [markdown]
# Decision Tree

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

# Parâmetros para otimizar na DecisionTree
parametros_dt = {
    'max_depth': [10, 20, 30],  
    'min_samples_split': [2, 5, 10],  
    'min_samples_leaf': [1, 2, 4]  
}

# GridSearchCV para DecisionTree
grid_search_dt = GridSearchCV(DecisionTreeClassifier(), parametros_dt, 
                            cv=10, n_jobs=-1, verbose=2)

# Fit do GridSearch no conjunto de treino
grid_search_dt.fit(X_train, y_train)

# Exibindo os melhores parâmetros encontrados para DecisionTree
print(f"Melhores parâmetros para a Decision Tree: {grid_search_dt.best_params_}")
# Out:
# Fitting 10 folds for each of 27 candidates, totalling 270 fits
# Melhores parâmetros para a Decision Tree: {'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 2}

# %% [markdown]
# Naive Bayes

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import MultinomialNB

# Parâmetros para otimizar no Naive Bayes
parametros_nb = {
    'alpha': [0.1, 0.5, 1.0]  
}

# GridSearchCV para Naive Bayes
grid_search_nb = GridSearchCV(MultinomialNB(), parametros_nb, 
                            cv=10, n_jobs=-1, verbose=2)

# Fit do GridSearch no conjunto de treino
grid_search_nb.fit(X_train, y_train)

# Exibindo os melhores parâmetros encontrados para Naive Bayes
print(f"Melhores parâmetros para o Naive Bayes: {grid_search_nb.best_params_}")
# Out:
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# Melhores parâmetros para o Naive Bayes: {'alpha': 0.1}

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

# Definindo o espaço de hiperparâmetros para o GridSearch
parametros_lr = {
    'C': [0.01, 0.1, 1, 10, 100],  
    'solver': ['liblinear', 'lbfgs', 'newton-cg'],  
    'max_iter': [100, 200, 300]  
}

# Aplicando GridSearchCV para otimizar os hiperparâmetros
grid_search_lr = GridSearchCV(LogisticRegression(), parametros_lr, 
                                cv=10, n_jobs=-1, verbose=2)

# Fit do GridSearch no conjunto de treino
grid_search_lr.fit(X_train, y_train)

# Mostrando os melhores hiperparâmetros encontrados
print("Melhores Hiperparâmetros para o Logistic Regression: ", grid_search_lr.best_params_)
# Out:
# Fitting 10 folds for each of 45 candidates, totalling 450 fits
# Melhores Hiperparâmetros:  {'C': 10, 'max_iter': 100, 'solver': 'liblinear'}

# %% [markdown]
# O MLPClassifier apresentou erros durante a execução de teste de Hiperparâmetros, meu PC travou completamente

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neural_network import MLPClassifier

# Definindo a grade de parâmetros para o MLP
parametros_mlp = {
    'hidden_layer_sizes': [(50,), (100,), (150,)],  
    'activation': ['relu', 'tanh'],  
    'alpha': [0.0001, 0.001, 0.01],  
    'learning_rate': ['constant', 'adaptive'],  
    'max_iter': [200, 300]  
}

# GridSearchCV para MLP
grid_search_mlp = GridSearchCV(MLPClassifier(), parametros_mlp, 
                            cv=10, n_jobs=-1, verbose=2)

# Fit do GridSearch no conjunto de treino
grid_search_mlp.fit(X_train, y_train)

# Exibindo os melhores parâmetros encontrados
print(f"Melhores parâmetros para o MLP: {grid_search_mlp.best_params_}")

# %% [markdown]
# ## Treino com Hiperparâmetros ajustados

# %% [markdown]
# KNN

# %%
# Criando o modelo KNN com os melhores parâmetros encontrados
modelo_knn_otimizado = KNeighborsClassifier(
    algorithm='auto',       
    n_neighbors=3,
    weights='uniform'
)

# Treinando o modelo otimizado
modelo_knn_otimizado.fit(X_train, y_train)
y_pred_knn = modelo_knn_otimizado.predict(X_test)

# Calculando as métricas
print("Acurácia no conjunto de teste (KNN Otimizado):", accuracy_score(y_test, y_pred_knn))
print("F1-Score no conjunto de teste (KNN Otimizado):", f1_score(y_test, y_pred_knn, average='weighted'))
# Out:
# Acurácia no conjunto de teste (KNN Otimizado): 0.6818181818181818
# F1-Score no conjunto de teste (KNN Otimizado): 0.686524500907441

# %% [markdown]
# Decision Tree

# %%
# Definindo o modelo com o melhor hiperparâmetro
modelo_dt_otimizado = DecisionTreeClassifier(
    max_depth=30,
    min_samples_leaf=4,
    min_samples_split=2
)

# Treinando o modelo no conjunto de treinamento
modelo_dt_otimizado.fit(X_train, y_train)
y_pred_dt = modelo_dt_otimizado.predict(X_test)

# Calculando as métricas
print("Acurácia no conjunto de teste (Decision Tree Otimizado):", accuracy_score(y_test, y_pred_dt))
print("F1-Score no conjunto de teste (Decision Tree Otimizado):", f1_score(y_test, y_pred_dt, average='weighted'))
# Out:
# Acurácia no conjunto de teste (Decision Tree Otimizado): 0.8068181818181818
# F1-Score no conjunto de teste (Decision Tree Otimizado): 0.8053200468294808

# %% [markdown]
# Naive Bayes

# %%
# Definindo o modelo com o melhor hiperparâmetro
modelo_nb_otimizado = MultinomialNB(alpha=0.1) 

# Treinando o modelo no conjunto de treinamento
modelo_nb_otimizado.fit(X_train, y_train)
y_pred_nb = modelo_nb_otimizado.predict(X_test)


print("Acurácia no conjunto de teste (Naive Bayes Otimizado):", accuracy_score(y_test, y_pred_nb))
print("F1-Score no conjunto de teste (Naive Bayes Otimizado):", f1_score(y_test, y_pred_nb, average='weighted'))
# Out:
# Avaliação no conjunto de teste (Naive Bayes Otimizado):
# Acurácia: 0.9432
# F1-Score: 0.9429

# %% [markdown]
# Logistic Regression

# %%
# Definindo o modelo com o melhor hiperparâmtro
modelo_lr_otimizado = LogisticRegression(C=10, 
                                         max_iter=100, 
                                         solver='liblinear')

# Treinando o modelo no conjunto de treinamento
modelo_lr_otimizado.fit(X_train, y_train)
y_pred_lr = modelo_lr_otimizado.predict(X_test)

print("Acurácia no conjunto de teste (Logistic Regression Otimizado):", accuracy_score(y_test, y_pred_lr))
print("F1-Score no conjunto de teste (Logistic Regression Otimizado):", f1_score(y_test, y_pred_lr, average='weighted'))
# Out:
# Acurácia no conjunto de teste (Logistic Regression Otimizado): 0.9431818181818182
# F1-Score no conjunto de teste (Logistic Regression Otimizado): 0.9425037925037923

# %% [markdown]
# MLP

# %% [markdown]
# Na minha maquina não roda, trava tudo

# %%
# Definindo o modelo com o melhor hiperparâmtro
modelo_mlp_otimizado = MLPClassifier(hidden_layer_sizes=(50,), 
                                     activation='relu',  
                                     solver='adam', 
                                     alpha=0.0001, 
                                     max_iter=200, 
                                     random_state=42)

# Treinando o modelo no conjunto de treinamento
grid_search_mlp.fit(X_train, y_train)
y_pred_mlp = modelo_mlp_otimizado.predict(X_test)

# Avaliando o desempenho do modelo otimizado
print("Acurácia no conjunto de teste (MLP Otimizado):", accuracy_score(y_test, y_pred_mlp))
print("F1-Score no conjunto de teste (MLP Otimizado):", f1_score(y_test, y_pred_mlp, average='weighted'))
